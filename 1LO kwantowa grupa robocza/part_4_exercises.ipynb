# %% [markdown]
# # Exercise 1
# Rework the above VQE example to return correct value of smallest eigenvalue (-0.59 found instead of -0.7)

# %% [markdown]
# # Exercise 2
# Run the above VQE algorithm on real quantum backend.

# %% [markdown]
# # Exercise 3:
# Using VQE algorithm calculate ground state energy of hydrogen molecule described by the below Hamiltonian.

# %%
H2_op = SparsePauliOp.from_list(
    [
        ("II", -1.052373245772859),
        ("IZ", 0.39793742484318045),
        ("ZI", -0.39793742484318045),
        ("ZZ", -0.01128010425623538),
        ("XX", 0.18093119978423156),
    ]
)

# %% [markdown]
# # Exercise 4
# Implement QAOA algorithm based on this tutorial: https://learning.quantum.ibm.com/tutorial/quantum-approximate-optimization-algorithm. \
# Using this implementation, solve MAXCUT for the following graph: \
# ![image.png](attachment:9f897471-8943-43d6-bc37-1847243c7db1.png)
