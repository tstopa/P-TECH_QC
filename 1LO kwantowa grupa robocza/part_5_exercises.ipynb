# %% [markdown]
# ### Exercise 1
# Using Qiskit:
# - choose the real backend on which you excuted some jobs in the past
# - list all the past jobs
# - choose the oldest job from the ones available and extract it's results
# - plot histogram based on the extyracted job results

# %% [markdown]
# ### Exercise 2
# Generate randon circuit using 100 qubits (Qiskit has function for it). Run it on real backend and get results.

# %% [markdown]
# ### Exercise 3
# Create circuit with Toffoli gate.
# Draw the circuit.
# Transpile the circuit for any backend few times (possibly with different optimization levels).
# Draw the circuits after each transpilation and count the gates.
# Count the gates programatically (Qiskit has functions for that).

# %% [markdown]
# ### Exercise 4
# Solve MAXCUT prpoblem using QAOA algorithm for the following weighted graph (google for the hamiltonian - but it is a trivial generalization of the regular MAXCUT problem):
# ![image.png](attachment:a2115664-bff8-4b1c-966d-65a75735dac6.png)
